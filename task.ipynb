# %%
# 1. Вычисляем сумму двух чисел
a = 10
b = 5
sum_result = a + b
print("Сумма двух чисел:", sum_result)

# 2. Находим среднее арифметическое трёх чисел
x = 4
y = 8
z = 12
average_result = (x + y + z) / 3
print("Среднее арифметическое трёх чисел:", average_result)

# 3. Выводим квадрат заданного числа
n = 7
square_result = n ** 2
print("Квадрат числа:", square_result)
# Out:
# Сумма двух чисел: 15
# Среднее арифметическое трёх чисел: 8.0
# Квадрат числа: 49
